# %% [markdown]
# <a href="https://colab.research.google.com/github/amit9129/amit9129/blob/main/US_honey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries  # Add explanation here if needed
import numpy as np  # For numerical computations  # Importing necessary libraries
import pandas as pd  # For handling dataframes  # Importing necessary libraries
import matplotlib.pyplot as plt  # For data visualization  # Importing necessary libraries
import seaborn as sns  # For statistical data visualization  # Importing necessary libraries

# %%
# Load the dataset  # Add explanation here if needed
df = pd.read_csv('/content/US_honey_dataset.csv')  # Read the CSV file into a DataFrame  # Reading dataset into a pandas DataFrame

# %%
# Display the first few rows of the dataset  # Add explanation here if needed
df  # Display the first few rows of the dataset
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
# Get an overview of the dataset structure  # Add explanation here if needed
df.info()  # Displays column data types and non-null values  # Get dataset information, including column types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
# Check for missing values in the dataset  # Add explanation here if needed
df.isnull().sum()  # Returns the count of null values in each column  # Check for missing values in each column
# Out:
# Unnamed: 0             0
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
#let suppose we had null values  # Add explanation here if needed
#df.dropna()  # Add explanation here if needed

# %%
#to check for the dupliacte values in the dataset  # Add explanation here if needed
df.duplicated().sum()  # Add explanation here if needed
# Out:
# 0

# %%
#let suppose it had duplicate value  # Add explanation here if needed
df.drop_duplicates()  # Add explanation here if needed
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)  # inplce --> used to apply permanenet changes to df  # Add explanation here if needed

# %%
df  # Display the first few rows of the dataset
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
#Goupby  # Add explanation here if needed

# %% [markdown]
# 1) Which states are rarely contributing to honey production for the last 27 years?

# %%
contri = df.groupby(['state'])['production'].sum().reset_index()  # Add explanation here if needed
contri  # Add explanation here if needed
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
rarely_contri=contri.sort_values(by='production',ascending=True)  # Add explanation here if needed
rarely_contri  # Add explanation here if needed
# Out:
#             state  production
# 16       Maryland     1975000
# 30       Oklahoma     2055000
# 33  SouthCarolina     2823000
# 13       Kentucky     3224000
# 15          Maine     4762000
# 39       Virginia     5153000
# 41   WestVirginia     6411000
# 35      Tennessee     6857000
# 24      NewJersey     6913000
# 38        Vermont     7032000
# 23         Nevada     7399000
# 27  NorthCarolina     8909000
# 10        Indiana     9686000
# 9        Illinois     9864000
# 25      NewMexico    10082000
# 12         Kansas    14138000
# 0         Alabama    14467000
# 7          Hawaii    15420000
# 20       Missouri    17904000
# 37           Utah    20369000
# 19    Mississippi    21235000
# 32   Pennsylvania    21370000
# 29           Ohio    22485000
# 4        Colorado    32660000
# 1         Arizona    38844000
# 31         Oregon    43789000
# 43        Wyoming    43921000
# 11           Iowa    48607000
# 2        Arkansas    51846000
# 40     Washington    53238000
# ...

# %%
rarely_contri.head()  # Add explanation here if needed
# Out:
#             state  production
# 16       Maryland     1975000
# 30       Oklahoma     2055000
# 33  SouthCarolina     2823000
# 13       Kentucky     3224000
# 15          Maine     4762000

# %% [markdown]
# 2) Which are the top 5 Honey producing states in the US ?

# %%
contri=df.groupby(['state'])['production'].sum().reset_index()  # Add explanation here if needed

# %%
highly_contri=contri.sort_values(by='production',ascending=False).head(5)  # Add explanation here if needed
highly_contri  # Add explanation here if needed
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000

# %% [markdown]
# 3) What is the Change in mean Average price of Honey from 1995 to 2021?

# %%
avg_df=df.groupby(['year'])['average_price'].mean()  # Add explanation here if needed
avg_df  # Add explanation here if needed
# Out:
# year
# 1995     74.840909
# 1996     99.568182
# 1997     91.325581
# 1998     83.720930
# 1999     80.325581
# 2000     79.023256
# 2001     88.465116
# 2002    133.204545
# 2003    151.068182
# 2004    132.350000
# 2005    116.341463
# 2006    134.341463
# 2007    140.170732
# 2008    160.878049
# 2009    176.195122
# 2010    192.900000
# 2011    216.725000
# 2012    236.700000
# 2013    260.717949
# 2014    282.025000
# 2015    292.625000
# 2016    291.925000
# 2017    302.775000
# 2018      3.083500
# 2019      2.925500
# 2020      3.050000
# 2021      3.334250
# Name: average_price, dtype: float64

# %%
change_mean=avg_df.loc[1995]-avg_df.loc[2021]  # Add explanation here if needed
change_mean  # Add explanation here if needed
# Out:
# 71.5066590909091

# %% [markdown]
# 4) Which was the year when production of Honey in wholeUS was the highest?

# %%
contribyyear=df.groupby(['year'])['production'].sum().reset_index()  # Add explanation here if needed
contribyyear  # Add explanation here if needed
# Out:
#     year  production
# 0   1995   210272000
# 1   1996   197995000
# 2   1997   191176000
# 3   1998   219321000
# 4   1999   204585000
# 5   2000   220320000
# 6   2001   185403000
# 7   2002   170732000
# 8   2003   180741000
# 9   2004   182379000
# 10  2005   173857000
# 11  2006   154120000
# 12  2007   147609000
# 13  2008   160096000
# 14  2009   143340000
# 15  2010    44797000
# 16  2011    36550000
# 17  2012    31662000
# 18  2013    37974000
# 19  2014    40990000
# 20  2015    41832000
# 21  2016    40837000
# 22  2017    30478000
# 23  2018    28989000
# 24  2019    40510000
# 25  2020    39412000
# 26  2021    23187000

# %%
high_contribyyear=contribyyear.sort_values(by='production',ascending=False).head()  # Add explanation here if needed
high_contribyyear  # Add explanation here if needed
# Out:
#    year  production
# 5  2000   220320000
# 3  1998   219321000
# 0  1995   210272000
# 4  1999   204585000
# 1  1996   197995000

# %% [markdown]
# 5) From the above inference we get the production was highest in the year 2000, now let
# infer which state was having highest contribution in that year

# %%
contri_year_state=df.groupby(['year','state'])['production'].sum().reset_index()  # Add explanation here if needed
contri_year_state  # Add explanation here if needed
# Out:
#       year         state  production
# 0     1995       Alabama      928000
# 1     1995       Arizona     4108000
# 2     1995      Arkansas     3000000
# 3     1995    California    39060000
# 4     1995      Colorado     2700000
# ...    ...           ...         ...
# 1110  2021      Virginia       79000
# 1111  2021    Washington     1206000
# 1112  2021  WestVirginia      136000
# 1113  2021     Wisconsin      750000
# 1114  2021       Wyoming      242000
#
# [1115 rows x 3 columns]

# %%
contri_2000 = contri_year_state.loc[contri_year_state['year']==2000]  # Add explanation here if needed
contri_2000  # Add explanation here if needed
# Out:
#      year          state  production
# 217  2000        Alabama     1248000
# 218  2000        Arizona     2360000
# 219  2000       Arkansas     5115000
# 220  2000     California    30800000
# 221  2000       Colorado     1740000
# 222  2000        Florida    24360000
# 223  2000        Georgia     3135000
# 224  2000         Hawaii      784000
# 225  2000          Idaho     4700000
# 226  2000       Illinois      488000
# 227  2000        Indiana      520000
# 228  2000           Iowa     2010000
# 229  2000         Kansas     1020000
# 230  2000       Kentucky      144000
# 231  2000      Louisiana     4042000
# 232  2000          Maine      231000
# 233  2000       Maryland      276000
# 234  2000       Michigan     5400000
# 235  2000      Minnesota    13500000
# 236  2000    Mississippi     1224000
# 237  2000       Missouri     1725000
# 238  2000        Montana    12728000
# 239  2000       Nebraska     4350000
# 240  2000         Nevada      350000
# ...

# %%
highly_2000=contri_2000.sort_values(by='production',ascending=True).tail(1)  # Add explanation here if needed
highly_2000  # Add explanation here if needed
# Out:
#      year        state  production
# 245  2000  NorthDakota    33350000

# %% [markdown]
# 6) Which states have the highest no. of colonies in the year 2000?

# %%
contri_year_state_col=df.groupby(['year','state'])['colonies_number'].sum().reset_index()  # Add explanation here if needed
contri_year_state_col  # Add explanation here if needed
# Out:
#       year         state  colonies_number
# 0     1995       Alabama            16000
# 1     1995       Arizona            52000
# 2     1995      Arkansas            50000
# 3     1995    California           420000
# 4     1995      Colorado            45000
# ...    ...           ...              ...
# 1110  2021      Virginia             6000
# 1111  2021    Washington            96000
# 1112  2021  WestVirginia             6000
# 1113  2021     Wisconsin            42000
# 1114  2021       Wyoming            38000
#
# [1115 rows x 3 columns]

# %%
contri_2000_col = contri_year_state_col.loc[contri_year_state['year']==2000]  # Add explanation here if needed
contri_2000_col  # Add explanation here if needed
# Out:
#      year          state  colonies_number
# 217  2000        Alabama            16000
# 218  2000        Arizona            40000
# 219  2000       Arkansas            55000
# 220  2000     California           440000
# 221  2000       Colorado            29000
# 222  2000        Florida           232000
# 223  2000        Georgia            55000
# 224  2000         Hawaii             7000
# 225  2000          Idaho           100000
# 226  2000       Illinois             8000
# 227  2000        Indiana             8000
# 228  2000           Iowa            30000
# 229  2000         Kansas            15000
# 230  2000       Kentucky             3000
# 231  2000      Louisiana            43000
# 232  2000          Maine            11000
# 233  2000       Maryland             6000
# 234  2000       Michigan            72000
# 235  2000      Minnesota           150000
# 236  2000    Mississippi            17000
# 237  2000       Missouri            23000
# ...

# %%
highly_2000_col=contri_2000_col.sort_values(by='colonies_number',ascending=True).tail(1)  # Add explanation here if needed
highly_2000_col  # Add explanation here if needed
# Out:
#      year       state  colonies_number
# 220  2000  California           440000
